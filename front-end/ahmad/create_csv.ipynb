# %%
import pandas as pd

# %%
csv = pd.read_csv("runs.csv")
csv
# Out:
#                                 Unique DAG ID  DAG Input Function Name  \
# 0     AS-0eea2507-ed93-4f74-998f-f515e97d493a   0.008837         wait1
# 1     AS-0eea2507-ed93-4f74-998f-f515e97d493a   0.008837          AES1
# 2     AS-0eea2507-ed93-4f74-998f-f515e97d493a   0.008837          AES2
# 3     AS-0eea2507-ed93-4f74-998f-f515e97d493a   0.008837          AES3
# 4     AS-0eea2507-ed93-4f74-998f-f515e97d493a   0.008837         Stats
# ...                                       ...        ...           ...
# 2484  AS-c31d19ad-4769-47b3-afc7-5d101cbb50da   0.006975         wait1
# 2485  AS-c31d19ad-4769-47b3-afc7-5d101cbb50da   0.006975          AES1
# 2486  AS-c31d19ad-4769-47b3-afc7-5d101cbb50da   0.006975          AES2
# 2487  AS-c31d19ad-4769-47b3-afc7-5d101cbb50da   0.006975          AES3
# 2488  AS-c31d19ad-4769-47b3-afc7-5d101cbb50da   0.006975         Stats
#
#       Input Feature  Duration  Parallel Duration  Memory_Allocated  \
# ...

# %%
for row in
# Out:
# Unique DAG ID
