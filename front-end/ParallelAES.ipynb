# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
#read from error_file as a txt file
# file_paths = {
#     'RandomForest': './logs/errors/RandomForest_memory_error_list.csv',
#     'XGBoost': './logs/errors/XGBoost_memory_error_list.csv',
#     'SVR': './logs/errors/SVR_memory_error_list.csv',
#     'NN': './logs/errors/BasicNN_memory_error_list.csv',
#     'DecisionTree': './logs/errors/DecisionTree_memory_error_list.csv',
#     'LinearRegression': './logs/errors/LinearRegression_memory_error_list.csv'
# }

file_paths = {
    'RandomForest': './logs/aes/errors/RandomForest_cpu_error_list.csv',
    'XGBoost': './logs/aes/errors/XGBoost_cpu_error_list.csv',
    # 'SVR': './logs/aes/errors/SVR_cpu_error_list.csv',
    # 'NN': './logs/aes/errors/BasicNN_cpu_error_list.csv',
    'DecisionTree': './logs/aes/errors/DecisionTree_cpu_error_list.csv',
    'LinearRegression': './logs/aes/errors/LinearRegression_cpu_error_list.csv'
}

# Initialize an empty DataFrame to combine all models' data
combined_data = pd.DataFrame()

# Loop through the file paths, read each CSV, add a model column, and append to the combined DataFrame
for model_name, file_path in file_paths.items():
    model_data = pd.read_csv(file_path, header=None)  # Assuming there's no header based on the first file structure
    model_data.columns = ['ErrorRate']  # Naming the column for clarity
    model_data['Model'] = model_name  # Add a column with the model name
    combined_data = pd.concat([combined_data, model_data])

# Display the first few rows of the combined DataFrame to verify the structure
# combined_data.head()



# Create a boxplot to visualize the error rates across different models
# Create a boxplot to visualize the error rates across different models
plt.figure(figsize=(12, 8))
sns.boxplot(x='Model', y='ErrorRate', data=combined_data, palette="Set3", showfliers=False)
# plt.title('Prediction Error Across Different Models for CPU Usage', fontsize=16)
plt.ylabel('Error (Cores)', fontsize=22)
plt.xlabel('Model', fontsize=22)
plt.xticks(rotation=45, fontsize=18)
plt.yticks(fontsize=18)  # Rotate model names for better readability
# plt.show()
# plt.savefig('./figures/memory_error_rate.png')
plt.savefig('/home/peiman/Desktop/figures/cpu_error_aes.pdf')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
#read from error_file as a txt file
# file_paths = {
#     'RandomForest': './logs/errors/RandomForest_memory_error_list.csv',
#     'XGBoost': './logs/errors/XGBoost_memory_error_list.csv',
#     'SVR': './logs/errors/SVR_memory_error_list.csv',
#     'NN': './logs/errors/BasicNN_memory_error_list.csv',
#     'DecisionTree': './logs/errors/DecisionTree_memory_error_list.csv',
#     'LinearRegression': './logs/errors/LinearRegression_memory_error_list.csv'
# }

file_paths = {
    'RandomForest': './logs/aes/errors/RandomForest_memory_error_list.csv',
    'XGBoost': './logs/aes/errors/XGBoost_memory_error_list.csv',
    # 'SVR': './logs/aes/errors/SVR_memory_error_list.csv',
    # 'NN': './logs/aes/errors/BasicNN_memory_error_list.csv',
    'DecisionTree': './logs/aes/errors/DecisionTree_memory_error_list.csv',
    'LinearRegression': './logs/aes/errors/LinearRegression_memory_error_list.csv'
}

# Initialize an empty DataFrame to combine all models' data
combined_data = pd.DataFrame()

# Loop through the file paths, read each CSV, add a model column, and append to the combined DataFrame
for model_name, file_path in file_paths.items():
    model_data = pd.read_csv(file_path, header=None)  # Assuming there's no header based on the first file structure
    model_data.columns = ['ErrorRate']  # Naming the column for clarity
    model_data['Model'] = model_name  # Add a column with the model name
    combined_data = pd.concat([combined_data, model_data])

# Display the first few rows of the combined DataFrame to verify the structure
# combined_data.head()



plt.figure(figsize=(12, 8))
sns.boxplot(x='Model', y='ErrorRate', data=combined_data, palette="Set3", showfliers=False)
# plt.title('Prediction Error Across Different Models for Memory Usage', fontsize=16)
plt.ylabel('Error (MB)', fontsize=22)
plt.xlabel('Model', fontsize=22)
plt.xticks(rotation=45, fontsize=18)
plt.yticks(fontsize=18)  # Rotate model names for better readability
# plt.show()
plt.savefig('/home/peiman/Desktop/figures/memory_error_aes.pdf')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
#read from error_file as a txt file
# file_paths = {
#     'RandomForest': './logs/errors/RandomForest_memory_error_list.csv',
#     'XGBoost': './logs/errors/XGBoost_memory_error_list.csv',
#     'SVR': './logs/errors/SVR_memory_error_list.csv',
#     'NN': './logs/errors/BasicNN_memory_error_list.csv',
#     'DecisionTree': './logs/errors/DecisionTree_memory_error_list.csv',
#     'LinearRegression': './logs/errors/LinearRegression_memory_error_list.csv'
# }

file_paths = {
    'RandomForest': './logs/aes/errors/RandomForest_input_size_error_list.csv',
    'XGBoost': './logs/aes/errors/XGBoost_input_size_error_list.csv',
    # 'SVR': './logs/aes/errors/SVR_input_size_error_list.csv',
    # 'NN': './logs/aes/errors/BasicNN_input_size_error_list.csv',
    'DecisionTree': './logs/aes/errors/DecisionTree_input_size_error_list.csv',
    # 'LinearRegression': './logs/aes/errors/LinearRegression_input_size_error_list.csv'
}

# Initialize an empty DataFrame to combine all models' data
combined_data = pd.DataFrame()

# Loop through the file paths, read each CSV, add a model column, and append to the combined DataFrame
for model_name, file_path in file_paths.items():
    model_data = pd.read_csv(file_path, header=None)  # Assuming there's no header based on the first file structure
    model_data.columns = ['ErrorRate']  # Naming the column for clarity
    model_data['Model'] = model_name  # Add a column with the model name
    combined_data = pd.concat([combined_data, model_data])

# Display the first few rows of the combined DataFrame to verify the structure
# combined_data.head()



# Create a boxplot to visualize the error rates across different models
plt.figure(figsize=(12, 8))
sns.boxplot(x='Model', y='ErrorRate', data=combined_data, palette="Set3", showfliers=False)
# plt.title('Prediction Error Across Different Models for Function Input Size', fontsize=16)
plt.ylabel('Error (Size)', fontsize=22)
plt.xlabel('Model', fontsize=22)
plt.xticks(rotation=45, fontsize=18)
plt.yticks(fontsize=18)  # Rotate model names for better readability
# plt.show()
# plt.savefig('./figures/memory_error_rate.png')
plt.savefig('/home/peiman/Desktop/figures/size_error_aes.pdf')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Placeholder accuracy data for each model
# Note: Replace these values with your actual model accuracy data
accuracy_data = {
    'Model': ['RandomForest', 'RandomForest', 'XGBoost', 'XGBoost', 'SVR', 'SVR', 'NN', 'NN', 'DecisionTree', 'DecisionTree', 'LinearRegression', 'LinearRegression'],
    'AccuracyType': ['CPU', 'Memory', 'CPU', 'Memory', 'CPU', 'Memory', 'CPU', 'Memory', 'CPU', 'Memory', 'CPU', 'Memory'],
    'Accuracy': [0.98, 0.98, 0.95, 0.93, 0.89, 0.93, 0.78, 0.79, 0.96, 0.99, 0.87, 0.85]  # Example accuracies; replace with your data
}

# Convert to DataFrame
accuracy_df = pd.DataFrame(accuracy_data)

# Create a bar plot to visualize the accuracy across different models
plt.figure(figsize=(12, 8))
sns.barplot(x='Model', y='Accuracy', hue='AccuracyType', data=accuracy_df, palette="Set2")
plt.title('Model Accuracy Comparison for CPU and Memory', fontsize=16)
plt.ylabel('Accuracy', fontsize=22)
plt.xlabel('Model', fontsize=22)

# Improve x-axis labels
plt.xticks(rotation=45, ha='right')

plt.legend(title='Resource Type')  # Add legend title

plt.tight_layout()  # Adjust layout for the plot
# plt.savefig('model_accuracy_comparison_cpu_memory.png')  # Save the plot as an image
# plt.show()  # Display the plot
plt.savefig('/home/peiman/Desktop/figures/acc_error_vid1.pdf')
accuracy_data = {
    'Model': ['RandomForest', 'RandomForest', 'XGBoost', 'XGBoost', 'SVR', 'SVR', 'NN', 'NN', 'DecisionTree', 'DecisionTree', 'LinearRegression', 'LinearRegression'],
    'AccuracyType': ['CPU', 'Memory', 'CPU', 'Memory', 'CPU', 'Memory', 'CPU', 'Memory', 'CPU', 'Memory', 'CPU', 'Memory'],
    'Accuracy': [0.99, 0.97, 0.94, 0.95, 0.82, 0.85, 0.93, 0.90, 0.97, 0.99, 0.86, 0.92]  # Example accuracies; replace with your data
}

# Convert to DataFrame
accuracy_df = pd.DataFrame(accuracy_data)

# Create a bar plot to visualize the accuracy across different models
plt.figure(figsize=(12, 8))
sns.barplot(x='Model', y='Accuracy', hue='AccuracyType', data=accuracy_df, palette="Set2")
# plt.title('Model Accuracy Comparison for CPU and Memory', fontsize=16)
plt.ylabel('Accuracy', fontsize=22)
plt.xlabel('Model', fontsize=22)

# Improve x-axis labels
plt.xticks(rotation=45, ha='right', fontsize=18)

plt.yticks(fontsize=18)  # Rotate model names for better readability

plt.legend(title='Resource Type', fontsize=18)  # Add legend title

plt.tight_layout()  # Adjust layout for the plot
# plt.savefig('model_accuracy_comparison_cpu_memory.png')  # Save the plot as an image
# plt.show()  # Display the plot
plt.savefig('/home/peiman/Desktop/figures/acc_error_aes.pdf')
